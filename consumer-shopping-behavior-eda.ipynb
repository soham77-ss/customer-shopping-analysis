# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/iamsouravbanerjee/customer-shopping-trends-dataset/shopping_trends.csv
# /kaggle/input/datasets/iamsouravbanerjee/customer-shopping-trends-dataset/shopping_trends_updated.csv

# %%
import pandas as pd
df = pd.read_csv("/kaggle/input/datasets/iamsouravbanerjee/customer-shopping-trends-dataset/shopping_trends_updated.csv")
df.head()
#Load the shopping trends dataset and display the first 5 rows.
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %%
df.describe()
#What is the total number of rows and columns in the dataset?
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df[(df['Age'] > 20) & (df['Age'] < 25)]
#Filter the dataset to view records for customers between the ages of 21 and 24(young gen)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3               4   21    Male        Sandals     Footwear
# 20             21   21    Male          Pants     Clothing
# 57             58   21    Male           Coat    Outerwear
# 70             71   22    Male           Belt  Accessories
# 77             78   22    Male          Dress     Clothing
# ...           ...  ...     ...            ...          ...
# 3770         3771   23  Female          Pants     Clothing
# 3771         3772   21  Female        T-shirt     Clothing
# 3830         3831   22  Female            Hat  Accessories
# 3848         3849   22  Female        Jewelry  Accessories
# 3893         3894   21  Female            Hat  Accessories
#
#       Purchase Amount (USD)       Location Size    Color  Season  \
# 3                        90   Rhode Island    M   Maroon  Spring
# 20                       51      Louisiana    M    Black  Winter
# 57                       64  West Virginia    M    White  Summer
# 70                       29        Alabama    M  Magenta    Fall
# 77                       53       Delaware    L     Gold  Summer
# ...                     ...            ...  ...      ...     ...
# 3770                     42        Montana    L    Black  Summer
# 3771                     86       Oklahoma    M      Red  Winter
# 3830                     27   Pennsylvania    M   Indigo  Summer
# 3848                     60  New Hampshire    M  Magenta  Winter
# 3893                     64  Massachusetts    L    White    Fall
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 3               3.5                 Yes    Next Day Air              Yes
# 20              2.8                 Yes         Express              Yes
# 57              4.4                 Yes    Store Pickup              Yes
# 70              4.2                 Yes         Express              Yes
# 77              3.3                 Yes    Next Day Air              Yes
# ...             ...                 ...             ...              ...
# 3770            4.0                  No    Store Pickup               No
# 3771            2.6                  No         Express               No
# 3830            3.0                  No  2-Day Shipping               No
# 3848            3.0                  No    Next Day Air               No
# 3893            3.3                  No    Store Pickup               No
#
#      Promo Code Used  Previous Purchases Payment Method Frequency of Purchases
# 3                Yes                  49         PayPal                 Weekly
# 20               Yes                  50           Cash         Every 3 Months
# 57               Yes                  17     Debit Card            Fortnightly
# 70               Yes                  32     Debit Card         Every 3 Months
# 77               Yes                  36     Debit Card            Fortnightly
# ...              ...                 ...            ...                    ...
# 3770              No                  34  Bank Transfer                 Weekly
# 3771              No                  28          Venmo              Bi-Weekly
# 3830              No                  33  Bank Transfer         Every 3 Months
# 3848              No                  39           Cash         Every 3 Months
# 3893              No                  29  Bank Transfer              Bi-Weekly
#
# [274 rows x 18 columns]

# %%
df[(df["Age"] >= 20) & (df["Age"] <= 25)]["Item Purchased"].value_counts().idxmax()
#What is the most frequently purchased item among customers aged 20 to 25?(young gen)
# Out:
# 'Sweater'

# %%
df[(df["Age"] >= 20) & (df["Age"] <= 25)]["Item Purchased"].value_counts().idxmin()
#What is the least frequently purchased item among customers aged 20 to 25?(young gen)
# Out:
# 'Shoes'

# %%
df[(df["Age"] >= 20) & (df["Age"] <= 25)]['Purchase Amount (USD)'].mean()
#What is the average purchase amount (in USD) for customers aged 20 to 25?(young gen)
# Out:
# np.float64(60.688836104513065)

# %%
df[df['Gender'] == 'Female']["Item Purchased"].value_counts().idxmax()
#What is the most popular item purchased by female customers?
# Out:
# 'Blouse'

# %%
df[df['Gender'] == 'Female']["Item Purchased"].value_counts().idxmin()
#What is the least popular item purchased by female customers?
# Out:
# 'Jeans'

# %%
df["Location"].value_counts().idxmax()
#Which location (state) has the highest number of customer purchases?
# Out:
# 'Montana'

# %%
df["Season"].value_counts().idxmax()
#What is the most popular season for shopping?
# Out:
# 'Spring'

# %%
df.groupby("Item Purchased")["Review Rating"].mean().sort_values(ascending=False).head(1)
#Which purchased item has the highest average review rating?
# Out:
# Item Purchased
# Gloves    3.864286
# Name: Review Rating, dtype: float64

# %%
df["Shipping Type"].value_counts().idxmin()
#What is the least commonly used shipping type?
# Out:
# '2-Day Shipping'

# %%
df["Subscription Status"].value_counts()
#How many customers have an active subscription versus no subscription?
# Out:
# Subscription Status
# No     2847
# Yes    1053
# Name: count, dtype: int64

# %%
df['Previous Purchases'].value_counts().idxmax()
#What is the most frequent number of previous purchases made by a customer?
# Out:
# np.int64(31)

# %%
df[(df["Age"] >= 20) & (df["Age"] <= 25)]["Payment Method"].value_counts().idxmax()
#What is the most popular payment method among customers aged 20 to 25?(young gen)
# Out:
# 'Cash'

# %%
df[df["Age"] > 35]["Payment Method"].value_counts().idxmax()
#What is the most popular payment method among customers older than 35?
# Out:
# 'PayPal'
